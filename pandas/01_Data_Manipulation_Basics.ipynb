# %% [markdown]
# # Data Manipulation with Pandas
# ## Essential Data Operations

# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Creating DataFrames

# %%
# Create DataFrame from dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'Salary': [50000, 60000, 75000, 55000],
    'Department': ['Sales', 'IT', 'HR', 'Sales']
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ## 2. Exploring Data

# %%
# Basic info
print('Shape:', df.shape)
print('\nData Types:\n', df.dtypes)
print('\nBasic Statistics:\n', df.describe())
print('\nMissing Values:\n', df.isnull().sum())

# %% [markdown]
# ## 3. Selecting Data

# %%
# Select single column
print(df['Name'])

# Select multiple columns
print(df[['Name', 'Salary']])

# Select by row index
print(df.iloc[0])

# Select by condition
print(df[df['Salary'] > 55000])

# %% [markdown]
# ## 4. Data Cleaning

# %%
# Create sample data with missing values
df_dirty = pd.DataFrame({
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, np.nan, 8],
    'C': [9, 10, 11, 12]
})

print('Original:')
print(df_dirty)

# Drop rows with missing values
print('\nAfter dropna:')
print(df_dirty.dropna())

# Fill missing values
print('\nAfter fillna:')
print(df_dirty.fillna(0))

# %% [markdown]
# ## 5. Grouping and Aggregation

# %%
# Group by Department
print('Average Salary by Department:')
print(df.groupby('Department')['Salary'].mean())

# Multiple aggregations
print('\nMultiple Statistics:')
print(df.groupby('Department')['Salary'].agg(['mean', 'sum', 'count']))

# %% [markdown]
# ## Exercises:
#
# 1. Filter employees with age > 28
# 2. Calculate the average salary across all departments
# 3. Add a new column 'Bonus' with 10% of salary
# 4. Sort by salary in descending order
